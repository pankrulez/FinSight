# %%
# Use this to verify your data before running the full app
import pandas as pd
import matplotlib.pyplot as plt
from src.data_engine.database import get_stock_data

df = get_stock_data("AAPL")
df['Close'].plot(title="AAPL Close Price (From DB)")
plt.show()
